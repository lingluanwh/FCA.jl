# %%
push!(LOAD_PATH, "../../src")
using FCA
using Colors, Images, FileIO, Plots, Statistics, LinearAlgebra, Random
# Out:
# ┌ Info: Recompiling stale cache file /Users/haowurm/.julia/compiled/v1.0/FCA.ji for FCA [top-level]
# └ @ Base loading.jl:1190

# %%
function extractpatches(image,patchsize,stride=1)
    return Matrix{eltype(image)}[image[i:i+patchsize-1,j:j+patchsize-1]
                    for i in 1:stride:size(image,1)-(patchsize-1),
                        j in 1:stride:size(image,2)-(patchsize-1)]
end
# Out:
# extractpatches (generic function with 2 methods)

# %%
image = "../images/panda.jpg"
img = Float64.(Gray.(load(image)))
Gray.(img)
# Out:
# 372×563 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.301961)  Gray{Float64}(0.286275)  …  Gray{Float64}(0.34902)
#  Gray{Float64}(0.301961)  Gray{Float64}(0.286275)     Gray{Float64}(0.34902)
#  Gray{Float64}(0.298039)  Gray{Float64}(0.286275)     Gray{Float64}(0.34902)
#  Gray{Float64}(0.298039)  Gray{Float64}(0.286275)     Gray{Float64}(0.356863)
#  Gray{Float64}(0.294118)  Gray{Float64}(0.290196)     Gray{Float64}(0.372549)
#  Gray{Float64}(0.294118)  Gray{Float64}(0.290196)  …  Gray{Float64}(0.392157)
#  Gray{Float64}(0.290196)  Gray{Float64}(0.290196)     Gray{Float64}(0.411765)
#  Gray{Float64}(0.290196)  Gray{Float64}(0.290196)     Gray{Float64}(0.427451)
#  Gray{Float64}(0.301961)  Gray{Float64}(0.294118)     Gray{Float64}(0.435294)
#  Gray{Float64}(0.298039)  Gray{Float64}(0.294118)     Gray{Float64}(0.423529)
#  Gray{Float64}(0.298039)  Gray{Float64}(0.294118)  …  Gray{Float64}(0.411765)
#  Gray{Float64}(0.294118)  Gray{Float64}(0.290196)     Gray{Float64}(0.4)
#  Gray{Float64}(0.290196)  Gray{Float64}(0.290196)     Gray{Float64}(0.384314)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.74902)   Gray{Float64}(0.752941)  …  Gray{Float64}(0.972549)
#  Gray{Float64}(0.803922)  Gray{Float64}(0.8)          Gray{Float64}(0.976471)
#  Gray{Float64}(0.788235)  Gray{Float64}(0.788235)     Gray{Float64}(0.976471)
#  Gray{Float64}(0.752941)  Gray{Float64}(0.756863)     Gray{Float64}(0.980392)
#  Gray{Float64}(0.756863)  Gray{Float64}(0.764706)     Gray{Float64}(0.980392)
#  Gray{Float64}(0.733333)  Gray{Float64}(0.745098)  …  Gray{Float64}(0.976471)
#  Gray{Float64}(0.67451)   Gray{Float64}(0.690196)     Gray{Float64}(0.976471)
#  Gray{Float64}(0.662745)  Gray{Float64}(0.662745)     Gray{Float64}(0.972549)
#  Gray{Float64}(0.65098)   Gray{Float64}(0.670588)     Gray{Float64}(0.972549)
#  Gray{Float64}(0.701961)  Gray{Float64}(0.717647)     Gray{Float64}(0.972549)
#  Gray{Float64}(0.690196)  Gray{Float64}(0.698039)  …  Gray{Float64}(0.972549)
#  Gray{Float64}(0.627451)  Gray{Float64}(0.639216)     Gray{Float64}(0.972549)

# %%
include("patch_displaying_utils.jl")
patches = extractpatches(img,8)
patchmat = hcat(vec.(patches)...);

# %%
@show size(patchmat)
viewpatches(rand(patches,(3,18)))
# Out:
# size(patchmat) = (64, 202940)
# 126×756 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  ⋮                          ⋱  ⋮
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)

# %%
batch_size = 50000
npatches = size(patchmat,2) 
rand_idx = randperm(npatches)[1:batch_size]
rand_patchmat = patchmat[:,rand_idx];

# %% [markdown]
# ## ICA patches

# %% [markdown]
# We regard these small patches are linear combinations of $64$ $\sf ICA$ components. Assume that the coefficient of a certain ICA component between different patches are i.i.d random variables. Further assume that the coefficents for different ICA components are independent, this patches can be regarded as generated following
# a ICA model:
#
# $$
#     patchmat = W_{ica} X_{ica}
# $$
#
# where columns of $W_{ica}$ is the vectorization of ICA components, $X_{ica}$, which represents the coefficients, is modeled as i.i.d samples of independent random variables.

# %%
Zica = [vec(rand_patchmat[i,:]) for i = 1: size(rand_patchmat, 1)];
@time Wica, Xica = icf(Zica; opt = "orth")
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] materialize at ./broadcast.jl:627 [inlined]
#  [2] grad_neg_abs_sum_kurt(::Array{Complex{Float64},2}, ::Array{Array{Float64,1},1}) at /Users/haowurm/Desktop/FCA.jl/src/icf.jl:151
#  [3] #63 at /Users/haowurm/Desktop/FCA.jl/src/icf.jl:45 [inlined]
#  [4] gg! at /Users/haowurm/.julia/packages/NLSolversBase/KG9Ie/src/objective_types/inplace_factory.jl:21 [inlined]
#  [5] (::getfield(NLSolversBase, Symbol("#fg!#8")){getfield(FCA, Symbol("##62#70")){Array{Array{Float64,1},1}},getfield(NLSolversBase, Symbol("#gg!#2")){getfield(FCA, Symbol("##63#71")){Array{Array{Float64,1},1}}}})(::Array{Complex{Float64},2}, ::Array{Complex{Float64},2}) at /Users/haowurm/.julia/packages/NLSolversBase/KG9Ie/src/objective_types/abstract.jl:13
#  [6] value_gradient!!(::NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}, ::Array{Complex{Float64},2}) at /Users/haowurm/.julia/packages/NLSolversBase/KG9Ie/src/interface.jl:82
#  [7] value_gradient!(::NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}, ::Array{Complex{Float64},2}) at /Users/haowurm/.julia/packages/NLSolversBase/KG9Ie/src/interface.jl:69
#  [8] value_gradient!(::Optim.ManifoldObjective{NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}}, ::Array{Complex{Float64},2}) at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/Manifolds.jl:50
#  [9] (::getfield(LineSearches, Symbol("#ϕdϕ#6")){Optim.ManifoldObjective{NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}},Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2}})(::Float64) at /Users/haowurm/.julia/packages/LineSearches/WrsMD/src/LineSearches.jl:84
#  [10] (::LineSearches.HagerZhang{Float64,Base.RefValue{Bool}})(::Function, ::getfield(LineSearches, Symbol("#ϕdϕ#6")){Optim.ManifoldObjective{NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}},Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2}}, ::Float64, ::Float64, ::Float64) at /Users/haowurm/.julia/packages/LineSearches/WrsMD/src/hagerzhang.jl:140
#  [11] HagerZhang at /Users/haowurm/.julia/packages/LineSearches/WrsMD/src/hagerzhang.jl:101 [inlined]
#  [12] perform_linesearch!(::Optim.GradientDescentState{Array{Complex{Float64},2},Float64}, ::Optim.GradientDescent{LineSearches.InitialPrevious{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Nothing,getfield(Optim, Symbol("##13#15"))}, ::Optim.ManifoldObjective{NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}}) at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:40
#  [13] update_state!(::NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}, ::Optim.GradientDescentState{Array{Complex{Float64},2},Float64}, ::Optim.GradientDescent{LineSearches.InitialPrevious{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Nothing,getfield(Optim, Symbol("##13#15"))}) at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/multivariate/solvers/first_order/gradient_descent.jl:74
#  [14] optimize(::NLSolversBase.OnceDifferentiable{Float64,Array{Complex{Float64},2},Array{Complex{Float64},2}}, ::Array{Complex{Float64},2}, ::Optim.GradientDescent{LineSearches.InitialPrevious{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Nothing,getfield(Optim, Symbol("##13#15"))}, ::Optim.Options{Float64,Nothing}, ::Optim.GradientDescentState{Array{Complex{Float64},2},Float64}) at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/multivariate/optimize/optimize.jl:57
#  [15] optimize at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/multivariate/optimize/optimize.jl:33 [inlined]
#  [16] #optimize#88(::Bool, ::Symbol, ::Function, ::Function, ::Function, ::Array{Complex{Float64},2}, ::Optim.GradientDescent{LineSearches.InitialPrevious{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Nothing,getfield(Optim, Symbol("##13#15"))}, ::Optim.Options{Float64,Nothing}) at /Users/haowurm/.julia/packages/Optim/ULNLZ/src/multivariate/optimize/interface.jl:121
#  [17] (::getfield(Optim, Symbol("#kw##optimize")))(::NamedTuple{(:inplace,),Tuple{Bool}}, ::typeof(Optim.optimize), ::Function, ::Function, ::Array{Complex{Float64},2}, ::Optim.GradientDescent{LineSearches.InitialPrevious{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Nothing,getfield(Optim, Symbol("##13#15"))}, ::Optim.Options{Float64,Nothing}) at ./none:0 (repeats 2 times)
#  [18] OptOrtho(::Function, ::Function, ::Int64) at /Users/haowurm/Desktop/FCA.jl/src/orthopt.jl:27
#  [19] #icf#59(::String, ::Function, ::Array{Array{Float64,1},1}) at /Users/haowurm/Desktop/FCA.jl/src/icf.jl:48
#  [20] (::getfield(FCA, Symbol("#kw##icf")))(::NamedTuple{(:opt,),Tuple{String}}, ::typeof(icf), ::Array{Array{Float64,1},1}) at ./none:0
#  [21] top-level scope at util.jl:156
#  [22] top-level scope at In[7]:2

# %% [markdown]
# ## FCA patches

# %% [markdown]
# We can regard those small patches are linear combinations of $63$ $\sf FCA$ components (the uniform one is removed as we assume the centered matrix).
# In contrast to $\sf ICA$ case, we do not make assumption on the coefficients.
# Instead, we regard $\sf FCA$ components are freely independent matrices.
#
# Reshaping the columns of $patchmat$ back to patches, we get an array $patcharr$ of $8 \times 8$ matrices. By above discussion, we have the decomposition
#
# $$
#     patcharr = W_{fca} X_{fca},
# $$
#
# where the free components in $X_{fca}$ stand for the $\sf FCA$ components and $W_{fca}$ denotes corresponding  coefficients.

# %%
patcharr = [reshape(rand_patchmat[:, i], (8,8)) for i = 1: size(rand_patchmat, 2)];

# %% [markdown]
# Note that if we set `batch_size` to be $50000$, $W_{fca}$ will be a $50000 \times 64$ matrix. The whitening process in FCF, whien being applied to `patcharr`, involves the eigenvalue decomposition of a $50000 \times 50000$ matrix. (We will take first $64$ eigenvalues and eigenvectors, as the rest eigenvalues are $0$ and irrelavant to the data.) This is time comsuming and unnecessary, a SVD for matrices is desired here.
#
# Note that the covariance of a pair of centered matrices $X_1, X_2 \in \mathbb R^{N \times M}$ is
#
# $$
#     \frac{1}{N} \mathrm{Tr}(X_1 \cdot X_2^T),
# $$
#
# which is equivalent to
#
# $$
#     \frac{1}{N} vec(X_1)^T \cdot vec(X_2).
# $$
#
# Therefore,
# The non-zero eigenvalues of
#
# $$
#     \left[\frac 1 N Tr.(patcharr[i]*patcharr[j]') \right]_{i,j = 1}^{50000}
# $$
#
# are $\frac1N \sigma_i^2$ where $\sigma_i$ denotes the non-zero singualr value of `patchmat`.
# The corresponding eigenvectors are exactly the right singular vectors of `patchmat`.
#
#
# Let us verify this in the following block.

# %%
# sample an array of 64 element
testarr = patcharr[1:64];

# results from free_whitening
Y, U, Σ = free_whiten(testarr; mat = "rec");

# results from applying SVD to the patchmat
testmat = rand_patchmat[:, 1:64]

# center the columns of testmat
testmat = testmat - ones(size(testmat, 1))* mean(testmat; dims = 1)

# SVD
Us, Σs, = svd(testmat');

# %%
heatmap(U'*Us)

# %%
## we now apply SVD to the 50000 patches
rand_patchmat = rand_patchmat - ones(size(rand_patchmat, 1))* mean(rand_patchmat; dims = 1);
U, Σ,  = svd(rand_patchmat');

## take first 63 singular value and singular vectors
U = U[:, 1: 63]
Σ = Σ[:, 1: 63]
# Out:
# BoundsError: attempt to access 64-element Array{Float64,1} at index [Base.Slice(Base.OneTo(64)), 1:63]
#
# Stacktrace:
#  [1] throw_boundserror(::Array{Float64,1}, ::Tuple{Base.Slice{Base.OneTo{Int64}},UnitRange{Int64}}) at ./abstractarray.jl:484
#  [2] checkbounds at ./abstractarray.jl:449 [inlined]
#  [3] _getindex at ./multidimensional.jl:596 [inlined]
#  [4] getindex(::Array{Float64,1}, ::Function, ::UnitRange{Int64}) at ./abstractarray.jl:905
#  [5] top-level scope at In[7]:7

# %%
## take first 63 singular value and singular vectors
U = U[:, 1: 63]
Σ = Σ[1: 63]
Y = pinv(Diagonal(Σ))*U'*[(reshape(rand_patchmat[:, i], (8,8)) 
        - mean(rand_patchmat[:, i]) * ones(8, 8)) for i = 1: size(rand_patchmat, 2)];

# %%
_, Xfca = freecf(Y; mat = "rec", opt = "sphe", obj = "kurt");
patchfca = [normpatch(Xfca[i]) for i in 1:63]
prepend!(patchfca, [0.5*ones(8,8)])
viewpatches(reshape(patchfca,(8,8)))
# Out:
# ┌ Warning: Linesearch failed, using alpha = 0.0 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /Users/haowurm/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 0.0 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /Users/haowurm/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# 336×336 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  ⋮                          ⋱  ⋮
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
